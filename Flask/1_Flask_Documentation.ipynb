# %% [markdown]
# # Flask Framework

# %%
# This framework is used to develop end to end web application which is created with python programming langauge.

# %%
# 1.  WSGI-> Web server gateway interface.
# 2. Jinga-2 Template Engine-> It is web template engine.
    # It combines web templates with data source.
        # Data Source-> SQL DB, CSV Sheet, ML Model, and MongoDB.


### It is used to create dynamic web page.


#### Ex-> There is image and if you click on button you have to identify image is of a dog or a cat. So we will use ML model for it which is integrate with web application.
