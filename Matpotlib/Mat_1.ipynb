# %% [markdown]
# # Introduction to Matplotlib

# %%
import matplotlib as mat
print(mat.__version__)
# Out:
# 3.10.5

# %% [markdown]
# Pyplot-> Module of Matplotlib

# %% [markdown]
# Plot-> Used to create a stright line and make graphs

# %% [markdown]
# Show used to display graphm

# %%
import matplotlib.pyplot as plt
x = [1,2,3,4]
y = [10,20,30,40]
plt.plot(x,y)
plt.show()

# %% [markdown]
# ## Terminology

# %%
'''
DataPoint-> 
    Values we used to show or display data.
X-axis/Y-axis-> 
    X-axis-> Horizontal Line; [Input Data]
    Y-axis-> Verticle Line ;[Output Data]
    ::"Mention your axis's".
Figure-> Where graphs are presented.
Axes-> Graph Box.
Plot-> Line, Bay and Shape which we are using in graph.
Marker-> Simboles and marker which used to mention points.
Line Style-> Type of line, like-> Dot and etc.
Color-> Color of line or graph.
Legend-> This is box which is represent the things.
Label-> Axis line denote
Title-> Head line.
Grid
Function-> Perform specific task.
Method-> Function which belong to method.
Parameters-> Control which used to help in draw graph.
Keyword Arguments-> Small things which we want to change.
Object Oriented API
DPI->Dop Per Inch, Clairt of Image. If DPI is high.
Backend-> Tkagg-> Used to save things.

'''
# Out:
# '\nDataPoint-> \n    Values we used to show or display data.\nX-axis/Y-axis-> \n    X-axis-> Horizontal Line\n\n'

# %% [markdown]
# ## Pyplot

# %%
# Imagine like you have paper and you need tools like-> Brush and etc, so similarly pyplot used like it.
# Also you can display and save things.

# %% [markdown]
# Basic Level Stuff

# %%
x= ['Mon','Tue','Wed','Thrus','Fri']
y = ['10','15','20','0','50']
plt.plot(x,y)
plt.title("Sales This Week")
plt.
